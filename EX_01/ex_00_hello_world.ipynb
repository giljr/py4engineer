# %%
print("hello")
# Out:
# hello

# %%
D=80
a=-0.102
b=0.222
Dmin=D+a
Dmax=D+b
print('Max Diameter: %.3f' % Dmax)
print('Min Diameter: %.3f' % Dmin)
# Out:
# Max Diameter: 80.222
# Min Diameter: 79.898

# %%
c=144010.00
n=14
i=1.3/100
m=c*(1+i)**n
print('The amount is: $ %.2f' %m)
# Out:
# The amount is: $ 172553.94

# %%
import numpy as np 
c=[-2,7,-20,6]
np.roots(c)
# Out:
# array([1.58217509+2.53665299j, 1.58217509-2.53665299j,
#        0.33564982+0.j        ])

# %%
import matplotlib.pyplot as plt 
x=['Jan', 'Feb', 'Mar','Apr', 'May']
y=[127000, 133000, 129000, 134000, 136000]
plt.plot(x,y)
plt.plot(x,y,'r o')
plt.title("Downloads - From January to May")
plt.xlabel('Month')
plt.ylabel('Downloads')
plt. show()

# %%
import matplotlib.pyplot as plt
x=[5226,2404,3218,4321]
snacks=['BigMac','McSpicy','Cheeseburger','McNuggets']
colors=['r','m','y','g']
plt.axis('equal')
plt.pie(x,labels=snacks,colors=colors,shadow=True,explode=(0.1,0,0,0),autopct=('%1.1f%%'))
plt.title('Snacks sold in a month')
plt.show()

# %%
from sympy import *
x,f=symbols("x f")
init_printing()
f=4*x**3+12*x-7
diff(f,x)
# Out:
#     2
# 12⋅x  + 12

# %%
from sympy import *
x,f=symbols("x f")
init_printing()
f=4*x**3+12*x-7
integrate(f,x)
# Out:
#  4      2
# x  + 6⋅x  - 7⋅x

# %%
import numpy as np 
A=np.array([[5,1,3],[-1,2,5],[4,-5,1]])
b=np.array([[76],[35],[22]])
x=np.linalg.solve(A, b)
print(x)
# Out:
# [[10.]
#  [ 5.]
#  [ 7.]]

# %%
from sympy import *
C,R,x=symbols("C R x")
init_printing()
R=193.57*x
C=129*x+18322.80
xp=solve(Eq(R,C),x)
yp=R.subs(x, xp[0])
print(xp[0])
print(yp)
# Out:
# 283.766455010067
# 54928.6726962986

# %%
import numpy as np 
import matplotlib.pyplot as pyp 
from scipy import stats
x=np.array([1,2,3,4,5,6])
y=np.array([134,126,141,145,139,142])
a,b,correlation,p,error=stats.linregress(x,y)
print('Regression line: y=%.2fx+%.2f'% (a,b))
print('Correlation Coefficient: r=%.2f'% correlation)
plt.plot(x,y,'o',label='Original data')
f=a*x+b
plt.plot(x,f,'r',label='Regression Line')
plt.ylim(110, 160)
plt.legend()
plt.show()
# Out:
# Regression line: y=2.37x+129.53
# Correlation Coefficient: r=0.65

# %%
from scipy.interpolate import *
x=[0,10,20]
y=[0,5,0]
f=lagrange(x,y)
print(f)
# Out:
# 2
# -0.05 x + 1 x

# %% [markdown]
# x1 = number of boxes of Prod A
#
# x1 = number of boxes of Prod B
#
# P =  4.10*x1 + 5.40*x2 (I)  -> Max (P)rofit
#
# c1 = 0.45*x1+0.35*x2 <= 30  -> Space (C)onstraint 1
#
# c2 = 20*x1+30*x2 <= 2000    -> Weight (C)onstraint 2

# %%
import sys
# !{sys.executable} -m pip install pulp

# %%
from pulp import *
prob=LpProblem('Example', LpMaximize)
x1=LpVariable("Product A", 0)
x2=LpVariable("Product B", 0)
prob += 4.10*x1 + 5.40*x2
prob += 0.45*x1+0.35*x2 <= 30
prob += 20*x1+30*x2 <= 2000
prob.solve()
for v in prob.variables():
    print(v.name,"=", v.varValue)
print("Max Profit = ", value(prob.objective))
# Out:
# Product_A = 30.769231
# Product_B = 46.153846
# Max Profit =  375.3846155

# %%
    print('hello')
# Out:
# hello
