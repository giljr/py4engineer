# %% [markdown]
# In January, a disposable cup industry had a cost of \$ 27,936.10 for the purchase of raw materials and \$ 1,243.90 for freight. Using Python, determine what was the total cost for purchasing the raw material?

# %%
raw=27936.10
freight=1243.90
total_cost = raw + freight
print('Total cost was: $%.2f' %total_cost)
# Out:
# Total cost was: $29180.00

# %% [markdown]
# Using Python, find the roots of the function y = 2x^2 + 10x-4.

# %%
import numpy as np 
c=[2,10,-4]
np.roots(c)
# Out:
# array([-5.37228132,  0.37228132])

# %% [markdown]
# A company's revenue is given by R (x) = 314x and costs by C (x) = 179x + 10530 where x is the marketed quantity of a given product. Determine the respective break-even point using Python.

# %%
from sympy import *
C,R,x=symbols("C R x")
init_printing()
R=314*x
C=179*x+10530
xp=solve(Eq(R,C),x)
yp=R.subs(x, xp[0])
print(xp[0])
print(yp)
# Out:
# 78
# 24492

# %% [markdown]
# A frozen meat industry conducted a study and concluded that the monthly profit p (x) is given as a function of the price x per kilo of frozen meat and this relationship is described by the polynomial p (x) = - 80x2 + 7900x- 5000. Determine for which values of x the monthly profit is zero.

# %% [markdown]
# Write the factored form of the expression x^2y^5 + 3x^3y^4-x^3y^6

# %%
from sympy import *
x,y = symbols("x y")
factor(x**2*y**5+3*x**3*y**4-x**3*y**6)
# Out:
#   2  4 ⎛   2          ⎞
# -x ⋅y ⋅⎝x⋅y  - 3⋅x - y⎠

# %%
A frozen meat industry conducted a study and concluded that the monthly profit p (x) is given as a function of the price x per kilo of frozen meat and this relationship is described by the polynomial p(x)=-80x+7900x-5000. Determine for which values of x the monthly profit is zero.

# %%
import numpy as np 
c=[-80,7900,-5000]
np.roots(c)
# Out:
# array([98.11297929,  0.63702071])

# %% [markdown]
# Calculate, using Python, the first derivative of each of the following functions:
# f(x)=2*x^5+23x^3=7x

# %%
from sympy import *
x,f=symbols("x f")
f=-2*x**5+23*x**3-7*x
diff(f,x, 2)
# Out:
#     ⎛         2⎞
# 2⋅x⋅⎝69 - 20⋅x ⎠

# %% [markdown]
# Given the vectors u = (7, 1, -9)
# and v = (3, -5, -4), calculate u.v and uXv

# %%
import numpy as np 
u=np.array([[7,1,-9]])
v=np.array([[3,-5,-4]])
uv=np.inner(u,v)
uXv=np.cross(u,v)
print(uv)
print(uXv)
# Out:
# [[52]]
# [[-49   1 -38]]

# %% [markdown]
# Obtain the regression line, using python, that best fits these points:
# A(3,6), B(4,4), C(7,11) and D(10,12)

# %%
import numpy as np
import matplotlib.pyplot as pyp
from scipy import stats
x=np.array([3,4,7,10])
y=np.array([6,4,11,12])
a,b,correlation,p,error=stats.linregress(x,y)
print('Regression line: y=%.2fx+%.2f'% (a,b))
print('Correlation Coefficient: r=%.2f'% correlation)
plt.plot(x,y,'o',label='Original data')
f=a*x+b
plt.plot(x,f,'r',label='Regression Line')
plt.ylim(0, 15)
plt.legend()
plt.show()
# Out:
# Regression line: y=1.10x+1.65
# Correlation Coefficient: r=0.90

# %% [markdown]
# Simple Interest: We can also calculate the amount, which is the total amount received or due, at the end of the time period. This value is the sum of the interest with initial value (principal).
#
# Your formula will be:
#
# M = C + J → M = C + C. i. t
#
# From the above equation, we therefore have the expression:
#
# M = C. (1 + i. t)
#
# For interest rate, we can use:
#
# M  = C + C.i.t -> M - C = C.i.t -> i = (M-C)/(C.t), then multiply by 100 to have the percentage rate;
#
# If the \$ 1,214.15 invoice was paid 19 days late for a total of \$ 1,223.11, what is the daily interest rate used?

# %%
C=1214.15
M=1223.11
t=19
i=(M-C)/(C*t)*100
print('The mensal daily is: %.5f %%'%i)
# Out:
# The mensal daily is: 0.03884 %

# %% [markdown]
# using python to evolve the equation: (12x^5-3x^4+4x^2)^2

# %%
from sympy import *
x,f= symbols("x f")
f=(12*x**5-3*x**4+4*x**2)**2
expand(f)
# Out:
#      10       9      8       7       6       4
# 144⋅x   - 72⋅x  + 9⋅x  + 96⋅x  - 24⋅x  + 16⋅x

# %% [markdown]
# Get through python the function that interpolates the points: A(3,6), B(4,4), C(7,11) and D(10,12):

# %%
from scipy.interpolate import *
x=[3,4,7,10]
y=[6,4,11,12]
f=lagrange(x,y)

print(f)
# Out:
# 3         2
# -0.2024 x + 3.917 x - 21.93 x + 42

# %% [markdown]
# Solve, using python, the linear programming problem:
#
# Maxz = 3*x1 + 4*x2 + 2*x3
#
# 1*x1+10*x2+4*x3 <= 120
#
# 4*x1+1*x2 <= 80
#
# 2*x2+3*x3 <= 78

# %%
from pulp import *
prob=LpProblem('Example', LpMaximize)
x1=LpVariable("Product A", 0)
x2=LpVariable("Product B", 0)
x3=LpVariable("Product C", 0)
prob += 3*x1 + 4*x2 + 2*x3
prob += 1*x1+10*x2+4*x3 <= 120
prob += 4*x1+1*x2 <= 80
prob += 2*x2+3*x3 <= 78
prob.solve()
for v in prob.variables():
    print(v.name,"=", v.varValue)
print("Max Profit = ", value(prob.objective))
# Out:
# Product_A = 20.0
# Product_B = 0.0
# Product_C = 25.0
# Max Profit =  110.0

# %% [markdown]
# the expression that relates the cost c referring to the daily production of x units in an industry is motorcycles is given by the function
# c (x) = 2x^2+7x+9000; get the cost for 30 units:

# %%
from sympy import *
x,y=symbols("x y")
y=2*x**2+7*x+9000
y.subs(x,30)
# Out:
# 11010

# %% [markdown]
# A car costs cash $64,700.00, but will be paid in 8 equal installments without interest; What is the value of each installment?

# %%
c=64700
t=8
bill=c/t
print(bill)
# Out:
# 8087.5

# %% [markdown]
# A resistor has a voltage y as a function of the current x described by the equation f(x)=x^2+8x, make the graph to illustrate the behavior of the resistor:

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.linspace(0, 100, 100)
y=x**2+8*x
plt.plot(x,y)
plt.xlabel('Current')
plt.ylabel('Tension')
plt.show()

# %% [markdown]
# Given the vectors u = (3, -2, 1) and v = (6, 5, -7), calculate u.v:

# %%
import numpy as np 
u=np.array([[3,-2,1]])
v=np.array([[6,5,-7]])
uv=np.inner(u,v)
uXv=np.cross(u,v)
print(uv)
# Out:
# [[1]]

# %% [markdown]
# The cost c for the daily production of x units of a certain product corresponds to c(x)=2x^2-40x+1000; What is the level of production that minimizes the cost?

# %%
import numpy as np 
c=[2,-40,1000]
np.roots(c)
# Out:
# array([10.+20.j, 10.-20.j])

# %% [markdown]
# Calculate the definite integral of the function f(x)=x^3+cos(x) in the range \[0,2\]:

# %%
from sympy import *
x,f=symbols("x f")
init_printing()
f=x**3+cos(x)
integrate(f,(x,0,2))
# Out:
# sin(2) + 4

# %% [markdown]
# Using python, solve the following linear system:
#
# 4x-3y+z=15
#
# x+y+3z=27
#
# 2x+3y-4z=31

# %%
import numpy as np
A=np.array([[4,-3,1],[1,1,3],[2,3,-4]])
b=np.array([[15],[27],[31]])
x=np.linalg.solve(A, b)
print(x)
# Out:
# [[9.2345679 ]
#  [8.35802469]
#  [3.13580247]]

# %% [markdown]
# Using Python, find the roots of the function f(x)=-2x^3+7x^2-20x+6.

# %%
import numpy as np 
c=[-2,7,-20,6]
np.roots(c)
# Out:
# array([1.58217509+2.53665299j, 1.58217509-2.53665299j,
#        0.33564982+0.j        ])

# %% [markdown]
# In a soccer match, an unusual move occurred: the goalkeeper, when shooting the goal, hit the ball inside the opponent's goal, the trajectory described by the ball was a parabola calculated by the f(x)=-0.008x^2+0.8x equation; determine the total distance between the point where the ball was kicked and the point where it touches the ground.

# %%
import numpy as np 
c=[-0.008,0.8,0]
np.roots(c)
# Out:
# array([100.,   0.])

# %% [markdown]
# Given the vectors u = (3, -2, 1) and v = (6, 5, -7), calculate u.v and uXv

# %%
import numpy as np 
u=np.array([[3,-2,1]])
v=np.array([[6,5,-7]])
uv=np.inner(u,v)
uXv=np.cross(u,v)
print(uv)
print(uXv)
# Out:
# [[1]]
# [[ 9 27 27]]

# %% [markdown]
# Calculate the indefinite integral of the function:
#
# f’(x) = x³+cos(x);

# %%
from sympy import *
x,f=symbols("x f")
init_printing()
f=x**3+cos(x)
integrate(f,x)
# Out:
#  4
# x
# ── + sin(x)
# 4

# %% [markdown]
# A company not opting for the simple Brazilian national (Super Simples), pays 68.18% of tax on the salary of each monthly employee and the total monthly cost referring to the wages plus tax of 12 employees, who receive the same salary, corresponds to $ 137,236.64. so what is the free salary for each of these employees?

# %%
salaries=137236.64
tax=1.6818
employees=12
salary=(salaries)/(tax*employees)
print('The salary of each employees is: $ %.2f' %salary)
# Out:
# The salary of each employees is: $ 6800.09

# %% [markdown]
# What is the second derivative of the function: f(x)=19x^6-33x^3+111x+19?

# %%
from sympy import *
x,f=symbols("x f")
f=-19*x**6-33*x**3+111*x+19
expand(diff(f,x, 2))
# Out:
#        4
# - 570⋅x  - 198⋅x

# %% [markdown]
# Let the function be f(x)=-4x2^+40x-7;
# Obtain the area between the graph of f delimited by the x axis
# Make the graph

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import sympy as sy 
x=np.linspace(-1,3,1000)
f=-4*x**2+40*x-7
plt.plot(x,f, color='blue')
plt.axhline(color='blue')
plt.fill_between(x,f, where=[(x>0.2)and(x<2)for x in x], color='green')

# %% [markdown]
# Let the function be f(x)=-4x2^+40x-7; Obtain the area between the graph of f delimited by the x axis Make the graph

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import sympy as sy
x,f=symbols("x f")
f=-4*x**2+40*x-7
A=integrate(f,(x))
x=np.linspace(-1,3,1000)
f=-4*x**2+40*x-7
plt.plot(x,f, color='blue')
plt.axhline(color='blue')
plt.fill_between(x,f, where=[(x>0.2)and(x<2)for x in x], color='green')
print('Area=', A)
# Out:
# Area= -4*x**3/3 + 20*x**2 - 7*x

# %% [markdown]
# Get the polynomials that interpolate the points: A(0,2), B(3,7) and C(10,-2):

# %%
from scipy.interpolate import *
x=[0,3,10]
y=[2,7,-2]
f=lagrange(x,y)
print(f)
# Out:
# 2
# -0.2952 x + 2.552 x + 2

# %% [markdown]
# Which is the line that interpolates the points: A(2,5) and B(7,10)?

# %%
from scipy.interpolate import *
x=[2,7]
y=[5,10]
f=lagrange(x,y)
print(f)
# Out:
# 1 x + 3

# %% [markdown]
# In a bicycle factory, production in the third month of a certain year was 2,000 units and production in the sixth month was 3,000 units; which is the line that interpolates these points (in thousands) ?

# %%
from scipy.interpolate import *
x=[3,6]
y=[2000,3000]
f=lagrange(x,y)
print(f/1000)
# Out:
# 0.3333 x + 1

# %% [markdown]
# Calculate the definite integral of the function f(x)=5x^2+3x+1 in the range x=0 and x=4.

# %%
from sympy import *
x,f=symbols("x f")
init_printing()
f=5*x**2+3*x+1
integrate(f,(x,0,4))
# Out:
# 404/3

# %% [markdown]
# The following table represents the sale of hospital equipment:
#
# 1-180
#
# 2-120
#
# 3-150
#
# 4-190
#
# 5-210
#
# which line best fits these points?

# %%
import numpy as np
import matplotlib.pyplot as pyp
from scipy import stats
x=np.array([1,2,3,4,5])
y=np.array([180,120,150,190,210])
a,b,correlation,p,error=stats.linregress(x,y)
print('Regression line: y=%.2fx+%.2f'% (a,b))
print('Correlation Coefficient: r=%.2f'% correlation)
plt.plot(x,y,'o',label='Original data')
f=a*x+b
plt.plot(x,f,'r',label='Regression Line')
plt.ylim(140, 200)
plt.legend()
plt.show()
# Out:
# Regression line: y=13.00x+131.00
# Correlation Coefficient: r=0.58

# %% [markdown]
# Calculate, using Python, the first derivative of each of the following functions: f(x)=18*x^4-14x^2+22*X-1.

# %%
from sympy import *
x,f=symbols("x f")
f=-18*x**4-14*x**2+22*x-1
diff(f,x)
# Out:
#       3
# - 72⋅x  - 28⋅x + 22

# %% [markdown]
# In a bicycle factory, production in the third month of a certain year was 2,000 units and production in the sixth month was 3,000 units; What is the forecast for the seventh month?

# %%
from scipy.interpolate import *
x=[3,6]
y=[2000,3000]
f=lagrange(x,y)
print(f/1000)
# Out:
# 0.3333 x + 1

# %%
from scipy.stats import linregress
x=[34,35,39,42,43,47]
y=[102,109,137,148,150,158]
slope=round(linregress(x,y).slope,1)
intercept=round(linregress(x,y).intercept,1)
print(f'y={intercept} + {slope}')
# Out:
# y=-46.0 + 4.5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
x=np.array([34,35,39,42,43,47])
y=np.array([102,109,137,148,150,158])
a,b,correlation,p,error=stats.linregress(x,y)
print('Regression line: y=%.2fx+%.2f'% (a,b))
print('Correlation Coefficient: r=%.2f'% correlation)
plt.plot(x,y,'o',label='Original data')
f=a*x+b
plt.plot(x,f,'r',label='Regression Line')
plt.ylim(100, 180)
plt.legend()
plt.show()
# Out:
# Regression line: y=4.50x+-46.00
# Correlation Coefficient: r=0.97

# %% [markdown]
# Suppose you want to buy some tapes and CDs. Does anyone really buy tapes anymore? Anyway, you can buy up to 11 tapes; You can buy up to 7 CDS, but you want at least 3; You must get enough tapes or CDs to hold at least 10 hours of music; Each tape holds about 45 minutes of music and each CD holds an hour a tape costs $8 and a CD costs $12; So how many tapes and CDs should you buy to minimize your cost?

# %%
from pulp import *
prob=LpProblem('Example', LpMaximize)
x1=LpVariable("Tape", 0)
x2=LpVariable("CD", 0)
prob += x1<=11
prob += x2>=3
prob += x2<=7
prob += 45*x1+60*x2<=600
prob += 8*x1+12*x2 
prob.solve()
for v in prob.variables():
    print(v.name,"=", v.varValue)
print("Total Cost = ", value(prob.objective))
# Out:
# CD = 7.0
# Tape = 4.0
# Total Cost =  116.0
